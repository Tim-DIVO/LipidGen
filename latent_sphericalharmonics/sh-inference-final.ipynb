# %%
import pandas as pd
import numpy as np
import healpy as hp
import tensorflow as tf
from tensorflow.keras import layers, models, Input
from deepsphere import HealpyGCNN, healpy_layers as hp_layer
import matplotlib.pyplot as plt
import glob
import os
# %matplotlib inline
print("GPUs visible to TF:", tf.config.list_physical_devices("GPU"))
# Out:
# 2025-06-04 17:47:54.996272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749052075.009985  143544 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749052075.014724  143544 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749052075.025491  143544 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749052075.025509  143544 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749052075.025510  143544 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749052075.025511  143544 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-04 17:47:55.029392: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPUs visible to TF: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
leaflet_type = 'outer'

all_folders = [
    d for d in os.listdir(".")
    if d.startswith("configf_") and os.path.isdir(d)
]

with open("training_output/outer_test_folders.txt", "r") as f:
    test_folders = [line.strip() for line in f if line.strip()]
with open("training_output/outer_train_folders.txt", "r") as f:
    train_folders = [line.strip() for line in f if line.strip()]

print('all folders', len(all_folders), 'train folders', len(train_folders), 'test folders', len(test_folders))
print(all_folders[0:5], train_folders[:5], test_folders[:5])
# Out:
# all folders 954 train folders 725 test folders 129
# ['configf_1377', 'configf_1797', 'configf_1157', 'configf_790', 'configf_2396'] ['configf_1966', 'configf_2866', 'configf_3389', 'configf_2407', 'configf_3877'] ['configf_2989', 'configf_577', 'configf_3568', 'configf_2808', 'configf_322']

# %%
dummy_dirs = ['configf_4095', 'configf_4092']

# %%
import os
import numpy as np
import healpy as hp

# --------------------  USER SETTINGS  --------------------
leaflet_type      = "outer"         # we only handle 'outer' here
lmax_phase_bg     = 44              # <<< SH degree for BACKGROUND (label 0) phase components
lmax_phase_fg     = 22              # <<< SH degree for FOREGROUND (labels 1,2,3) phase components
lmax_radial       = 14              # SH degree for radial map
config_root_glob  = "configf_"      # directories that start with this
analysis_subdir   = "analysis_output"

# File names inside each analysis_output folder
radial_fname      = "area_outer_radial_dist.npy"
phase_files       = [                 # 3 mutually-exclusive phase maps
    "nmfk_phase_map_OUTER_UNS_vs_SAT.npy",
    "nmfk_phase_map_OUTER_SAT_vs_CHOL.npy",
    "nmfk_phase_map_OUTER_CHOL_vs_UNS.npy"
]
N_FOREGROUND_CLASSES_PER_PHASEMAP = 3 # Labels 1, 2, 3
# ----------------------------------------------------------

# -------- helper to shift cluster labels:  NaN→0,  1,2,3 stay positive
def fill_and_shift(arr):
    out           = np.empty_like(arr, dtype=np.float32)
    mask_nan      = np.isnan(arr)
    out[mask_nan] = 0.0             # NaN (true background) becomes 0
    out[~mask_nan] = arr[~mask_nan] + 1.0  # Original 0,1,2 become 1,2,3
    return out
# ----------------------------------------------------------

# Calculate latent dimensions based on new lmax parameters
latent_dim_phase_bg  = hp.Alm.getsize(lmax_phase_bg)
latent_dim_phase_fg  = hp.Alm.getsize(lmax_phase_fg)
latent_dim_radial    = hp.Alm.getsize(lmax_radial)

# -----------------------------------------------------------------
# loop over every configf_* directory
# -----------------------------------------------------------------
all_dirs = sorted([d for d in os.listdir(".")
                   if d.startswith(config_root_glob) and os.path.isdir(d)])

print(f"Found {len(all_dirs)} folders matching '{config_root_glob}*'")

for cfg_idx, cfg in enumerate(all_dirs, 1):
    path = os.path.join(cfg, analysis_subdir)
    try:
        radial_data = np.load(os.path.join(path, radial_fname))
        phase_maps_processed = [fill_and_shift(np.load(os.path.join(path, f)))
                                for f in phase_files]
    except FileNotFoundError as e:
        print(f"[{cfg}] missing expected file – skipped ({e})")
        continue

    n_frames, n_pix = radial_data.shape
    
    # Initialize latent arrays
    # Background: 1 component per phase_map_type (total 3 BG components)
    phase_latent_bg  = np.zeros((n_frames, latent_dim_phase_bg, len(phase_files)), dtype=np.complex128)
    
    # Foreground: N_FOREGROUND_CLASSES_PER_PHASEMAP components per phase_map_type
    num_total_fg_channels = len(phase_files) * N_FOREGROUND_CLASSES_PER_PHASEMAP
    phase_latent_fg  = np.zeros((n_frames, latent_dim_phase_fg, num_total_fg_channels), dtype=np.complex128)
    
    radial_latent = np.zeros((n_frames, latent_dim_radial, 1), dtype=np.complex128)

    for t in range(n_frames):
        # ---------- radial latent (1 channel) ----------
        alm_rad = hp.map2alm(radial_data[t], lmax=lmax_radial)
        radial_latent[t, :, 0] = alm_rad

        # ---------- phase latents with separate lmax for BG and FG ----------
        current_fg_latent_ch_idx = 0 # Index for the combined FG latent array
        for phase_map_type_idx, phase_map_data_for_type in enumerate(phase_maps_processed):
            labels_this_type = phase_map_data_for_type[t] # Values {0,1,2,3}
            
            # Process Background component (label 0) for this phase_map_type
            bg_one_hot_map = (labels_this_type == 0).astype(float)
            alm_bg = hp.map2alm(bg_one_hot_map, lmax=lmax_phase_bg)
            phase_latent_bg[t, :, phase_map_type_idx] = alm_bg
            
            # Process Foreground components (labels 1, 2, 3) for this phase_map_type
            for fg_label_value in range(1, N_FOREGROUND_CLASSES_PER_PHASEMAP + 1): # Iterates 1, 2, 3
                fg_one_hot_map = (labels_this_type == fg_label_value).astype(float)
                alm_fg = hp.map2alm(fg_one_hot_map, lmax=lmax_phase_fg)
                phase_latent_fg[t, :, current_fg_latent_ch_idx] = alm_fg
                current_fg_latent_ch_idx += 1

    # ------------------- save -------------------
    out_phase_bg = os.path.join(cfg, f"{leaflet_type}_sh_phase_latent_bg_lmax{lmax_phase_bg}.npy")
    out_phase_fg = os.path.join(cfg, f"{leaflet_type}_sh_phase_latent_fg_lmax{lmax_phase_fg}.npy")
    out_radial   = os.path.join(cfg, f"{leaflet_type}_sh_radial_latent.npy")
    
    np.save(out_phase_bg, phase_latent_bg)
    np.save(out_phase_fg, phase_latent_fg)
    np.save(out_radial,   radial_latent)

    print(f"[{cfg_idx:>3}/{len(all_dirs)}]  saved BG:{phase_latent_bg.shape} -> {os.path.basename(out_phase_bg)} | "
          f"FG:{phase_latent_fg.shape} -> {os.path.basename(out_phase_fg)} | "
          f"Rad:{radial_latent.shape} -> {os.path.basename(out_radial)}")

print("✅  All folders processed.")
# Out:
# Found 954 folders matching 'configf_*'
# [  1/954]  saved BG:(68, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(68, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(68, 120, 1) -> outer_sh_radial_latent.npy
# [  2/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  3/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  4/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  5/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  6/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  7/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  8/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [  9/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 10/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 11/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 12/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 13/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 14/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 15/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 16/954]  saved BG:(85, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(85, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(85, 120, 1) -> outer_sh_radial_latent.npy
# [ 17/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 18/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 19/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 20/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 21/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 22/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 23/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 24/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 25/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 26/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 27/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 28/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 29/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 30/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 31/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 32/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 33/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 34/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 35/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 36/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 37/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 38/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 39/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 40/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 41/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 42/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 43/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 44/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 45/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 46/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 47/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 48/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 49/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 50/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 51/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 52/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 53/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 54/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 55/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 56/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 57/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 58/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 59/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 60/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 61/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 62/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 63/954]  saved BG:(86, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(86, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(86, 120, 1) -> outer_sh_radial_latent.npy
# [ 64/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 65/954]  saved BG:(83, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(83, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(83, 120, 1) -> outer_sh_radial_latent.npy
# [ 66/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 67/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 68/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 69/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 70/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 71/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 72/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 73/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 74/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 75/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 76/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 77/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 78/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 79/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 80/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 81/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 82/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 83/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 84/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 85/954]  saved BG:(99, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(99, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(99, 120, 1) -> outer_sh_radial_latent.npy
# [ 86/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 87/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 88/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 89/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 90/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 91/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 92/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 93/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 94/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 95/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 96/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 97/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 98/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [ 99/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [100/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [101/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [102/954]  saved BG:(90, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(90, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(90, 120, 1) -> outer_sh_radial_latent.npy
# [103/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [104/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [105/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [106/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [107/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [108/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [109/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [110/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [111/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [112/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [113/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [114/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [115/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [116/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [117/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [118/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [119/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [120/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [121/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [122/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [123/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [124/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [125/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [126/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [127/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [128/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [129/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [130/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [131/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [132/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [133/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [134/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [135/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [136/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [137/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [138/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [139/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [140/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [141/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [142/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [143/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [144/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [145/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [146/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [147/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [148/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [149/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [150/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [151/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [152/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [153/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [154/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [155/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [156/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [157/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [158/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [159/954]  saved BG:(94, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(94, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(94, 120, 1) -> outer_sh_radial_latent.npy
# [160/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [161/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [162/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [163/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [164/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [165/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [166/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [167/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [168/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [169/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [170/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [171/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [172/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [173/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [174/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [175/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [176/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [177/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [178/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [179/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [180/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [181/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [182/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [183/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [184/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [185/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [186/954]  saved BG:(95, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(95, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(95, 120, 1) -> outer_sh_radial_latent.npy
# [187/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [188/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [189/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [190/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [191/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [192/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [193/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [194/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [195/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [196/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [197/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [198/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [199/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [200/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [201/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [202/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [203/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [204/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [205/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [206/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [207/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [208/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [209/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [210/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [211/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [212/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [213/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [214/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [215/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [216/954]  saved BG:(86, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(86, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(86, 120, 1) -> outer_sh_radial_latent.npy
# [217/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [218/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [219/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [220/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [221/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [222/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [223/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [224/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [225/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [226/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [227/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [228/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [229/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [230/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [231/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [232/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [233/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [234/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [235/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [236/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [237/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [238/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [239/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [240/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [241/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [242/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [243/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [244/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [245/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [246/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [247/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [248/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [249/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [250/954]  saved BG:(83, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(83, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(83, 120, 1) -> outer_sh_radial_latent.npy
# [251/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [252/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [253/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [254/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [255/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [256/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [257/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [258/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [259/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [260/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [261/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [262/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [263/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# ...
# [868/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [869/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [870/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [871/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [872/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [873/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [874/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [875/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [876/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [877/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [878/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [879/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [880/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [881/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [882/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [883/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [884/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [885/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [886/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [887/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [888/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [889/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [890/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [891/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [892/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [893/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [894/954]  saved BG:(77, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(77, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(77, 120, 1) -> outer_sh_radial_latent.npy
# [895/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [896/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [897/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [898/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [899/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [900/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [901/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [902/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [903/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [904/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [905/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [906/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [907/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [908/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [909/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [910/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [911/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [912/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [913/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [914/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [915/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [916/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [917/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [918/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [919/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [920/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [921/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [922/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [923/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [924/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [925/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [926/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [927/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [928/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [929/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [930/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [931/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [932/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [933/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [934/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [935/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [936/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [937/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [938/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [939/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [940/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [941/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [942/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [943/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [944/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [945/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [946/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [947/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [948/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [949/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [950/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [951/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [952/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [953/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# [954/954]  saved BG:(101, 1035, 3) -> outer_sh_phase_latent_bg_lmax44.npy | FG:(101, 276, 9) -> outer_sh_phase_latent_fg_lmax22.npy | Rad:(101, 120, 1) -> outer_sh_radial_latent.npy
# ✅  All folders processed.
